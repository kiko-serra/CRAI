# %%
import pandas as pd
from sklearn import metrics
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

iris = pd.read_csv('../final_csv/reduced_iris.csv')
raisin = pd.read_csv('../final_csv/reduced_raisin.csv')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier

num_columns = iris.shape[1]
print("Number of columns:", num_columns)
iris = iris[['Species', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
iris_columns = iris.columns
raisin_columns = raisin.columns

accuracy_overall = []

data = iris

X = data.drop('Species', axis=1)
y = data['Species']
#  usar stratified kfold
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75)

knn_classifier = KNeighborsClassifier()

# Train the classifier
knn_classifier.fit(X_train, y_train)

y_pred = knn_classifier.predict(X_test)

accuracy = round(metrics.accuracy_score(y_test, y_pred), 2)
accuracy_overall.append(accuracy)
#f1_score = round(metrics.f1_score(y_test, y_pred), 2)
#auc_score = round(roc_auc_score(y_test, y_pred), 2)
cross_val_scores = cross_val_score(knn_classifier, X, y, cv=4)
cross_val_scores = [round(score, 2) for score in cross_val_scores]


print("Accuracy:", accuracy)
#print("F1 Score:", f1_score)
#print("AUC Score:", auc_score)
print("Cross-Validation Scores:", cross_val_scores)

for index in range(num_columns):
    print("\nRaisin Column:", raisin_columns[index], " -- ", iris_columns[index], "\n\n")
    data[iris_columns[index]] = raisin[raisin_columns[index]]

    X = data.drop('Species', axis=1)
    Y = data['Species']

    n_splits = 10

    skf = StratifiedKFold(n_splits, shuffle=True, random_state=10)
    average_accuracy=0
    for fold, (train_index, test_index) in enumerate(skf.split(X, Y)):
        X_train = X.take(train_index)
        y_train = Y.take(train_index)
        X_test = X.take(test_index)
        y_test = Y.take(test_index)

        knn_classifier = KNeighborsClassifier()
        knn_classifier.fit(X_train, y_train)

        y_pred = knn_classifier.predict(X_test)

        accuracy = round(metrics.accuracy_score(y_test, y_pred), 2)
        average_accuracy = average_accuracy + accuracy
        print("Accuracy:", accuracy)
        #f1_score = round(metrics.f1_score(y_test, y_pred), 2)
        #auc_score = round(roc_auc_score(y_test, y_pred), 2)
        cross_val_scores = cross_val_score(knn_classifier, X, y, cv=4)
        cross_val_scores = [round(score, 2) for score in cross_val_scores]


        print("Accuracy:", accuracy)
        #print("F1 Score:", f1_score)
        #print("AUC Score:", auc_score)
        print("Cross-Validation Scores:", cross_val_scores)

    average_accuracy = average_accuracy/n_splits
    accuracy_overall.append(average_accuracy)

plt.plot(accuracy_overall)
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Accuracy Overall')
plt.show()
# Out:
# Number of columns: 5
# Accuracy: 1.0
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
#
# Raisin Column: class  --  Species
#
#
#      Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0          0            5.1           3.5            1.4           0.2
# 1          0            4.9           3.0            1.4           0.2
# 2          0            4.7           3.2            1.3           0.2
# 3          0            4.6           3.1            1.5           0.2
# 4          0            5.0           3.6            1.4           0.2
# ..       ...            ...           ...            ...           ...
# 145        1            6.7           3.0            5.2           2.3
# 146        1            6.3           2.5            5.0           1.9
# 147        1            6.5           3.0            5.2           2.0
# 148        1            6.2           3.4            5.4           2.3
# 149        1            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.67
# Accuracy: 0.67
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.93
# Accuracy: 0.93
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.67
# Accuracy: 0.67
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
# Accuracy: 0.93
# Accuracy: 0.93
# Cross-Validation Scores: [0.97, 0.95, 0.95, 1.0]
#
# Raisin Column: majoraxislength  --  SepalLengthCm
#
#
#      Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0          0     442.246011           3.5            1.4           0.2
# 1          0     406.690687           3.0            1.4           0.2
# 2          0     442.267048           3.2            1.3           0.2
# 3          0     286.540559           3.1            1.5           0.2
# 4          0     352.190770           3.6            1.4           0.2
# ..       ...            ...           ...            ...           ...
# 145        1     655.398966           3.0            5.2           2.3
# 146        1     458.844007           2.5            5.0           1.9
# 147        1     699.618264           3.0            5.2           2.0
# 148        1     518.787614           3.4            5.4           2.3
# 149        1     360.815292           3.0            5.1           1.8
#
# [150 rows x 5 columns]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.93
# Accuracy: 0.93
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.93
# Accuracy: 0.93
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 0.93
# Accuracy: 0.93
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
# Accuracy: 1.0
# Accuracy: 1.0
# Cross-Validation Scores: [0.5, 0.55, 0.51, 0.43]
#
# Raisin Column: perimeter  --  SepalWidthCm
#
#
#      Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0          0     442.246011      1184.040            1.4           0.2
# 1          0     406.690687      1121.786            1.4           0.2
# 2          0     442.267048      1208.575            1.3           0.2
# 3          0     286.540559       844.162            1.5           0.2
# 4          0     352.190770      1073.251            1.4           0.2
# ..       ...            ...           ...            ...           ...
# 145        1     655.398966      1626.909            5.2           2.3
# 146        1     458.844007      1202.583            5.0           1.9
# 147        1     699.618264      1754.378            5.2           2.0
# 148        1     518.787614      1365.577            5.4           2.3
# 149        1     360.815292       980.390            5.1           1.8
#
# [150 rows x 5 columns]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.67
# Accuracy: 0.67
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.93
# Accuracy: 0.93
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
# Accuracy: 0.93
# Accuracy: 0.93
# Cross-Validation Scores: [0.45, 0.42, 0.54, 0.49]
#
# Raisin Column: convexarea  --  PetalLengthCm
#
#
#      Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0          0     442.246011      1184.040          90546           0.2
# 1          0     406.690687      1121.786          78789           0.2
# 2          0     442.267048      1208.575          93717           0.2
# 3          0     286.540559       844.162          47336           0.2
# 4          0     352.190770      1073.251          81463           0.2
# ..       ...            ...           ...            ...           ...
# 145        1     655.398966      1626.909         160709           2.3
# 146        1     458.844007      1202.583          88521           1.9
# 147        1     699.618264      1754.378         181412           2.0
# 148        1     518.787614      1365.577         115550           2.3
# 149        1     360.815292       980.390          59797           1.8
#
# [150 rows x 5 columns]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.5, 0.47, 0.46, 0.41]
#
# Raisin Column: area  --  PetalWidthCm
#
#
#      Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0          0     442.246011      1184.040          90546         87524
# 1          0     406.690687      1121.786          78789         75166
# 2          0     442.267048      1208.575          93717         90856
# 3          0     286.540559       844.162          47336         45928
# 4          0     352.190770      1073.251          81463         79408
# ..       ...            ...           ...            ...           ...
# 145        1     655.398966      1626.909         160709        155702
# 146        1     458.844007      1202.583          88521         84295
# 147        1     699.618264      1754.378         181412        177206
# 148        1     518.787614      1365.577         115550        110897
# 149        1     360.815292       980.390          59797         56903
#
# [150 rows x 5 columns]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.73
# Accuracy: 0.73
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.8
# Accuracy: 0.8
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
# Accuracy: 0.87
# Accuracy: 0.87
# Cross-Validation Scores: [0.58, 0.47, 0.49, 0.43]
